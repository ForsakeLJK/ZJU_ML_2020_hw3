# %% [markdown]
# # K-Nearest Neighbor
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **K-Nearest Neighbor** algorithm
# - play with the hyperparameter K
# - try KNN on **real-world data**, i.e. the CAPTCHA of a website in ZJU
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib notebook


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### KNN experiment with hyperparameter K

# %%
from mkdata import mkdata
from knn_plot import knn_plot

[X, y] = mkdata()

K = [1, 10, 100]
for k in K:
    knn_plot(X, y, k)

# %% [markdown]
# ### Now Let's hack the website http://cwcx.zju.edu.cn/WFManager/login.jsp

# %%
from hack import hack
from extract_image import extract_image
from show_image import show_image

test_img = 'CAPTCHA_test/0.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([8., 3., 0., 6.])

# %%
test_img = 'CAPTCHA_test/1.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([4., 7., 6., 3.])

# %%
test_img = 'CAPTCHA_test/2.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([8., 4., 5., 9.])

# %%
test_img = 'CAPTCHA_test/3.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([7., 1., 7., 0.])

# %%
test_img = 'CAPTCHA_test/4.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([9., 0., 4., 3.])

# %%
test_img = 'CAPTCHA_test/5.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([1., 9., 6., 4.])

# %%
test_img = 'CAPTCHA_test/6.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([9., 8., 7., 3.])

# %%
test_img = 'CAPTCHA_test/7.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([6., 7., 1., 5.])

# %%
test_img = 'CAPTCHA_test/8.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([2., 1., 7., 2.])

# %%
test_img = 'CAPTCHA_test/9.jpg' 
x = extract_image(test_img)
show_image(x)
hack(test_img)
# Out:
# array([0., 7., 2., 2.])
